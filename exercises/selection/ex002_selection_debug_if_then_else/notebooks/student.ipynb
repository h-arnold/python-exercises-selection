# %% [markdown]
# # Selection — Debug Errors
#
# ## Goal
# In this notebook you will fix common errors that beginners make when writing `if` statements in Python. Each exercise contains a broken program — find the bug(s) and make the code work correctly.
#
# ## How to work
# - Each exercise shows the **expected output** — your job is to make the buggy code produce that output
# - Fix the code in the tagged cell and run it to check your fix
# - After fixing, write what you found in the explanation cell.
#
# ## Tips
# - Read the error message carefully — it tells you exactly what is wrong
# - Common issues: missing colons, wrong operators, indentation, and type mismatches

# %% [markdown]
# ## Exercise 1 — Even or odd?
#
# **Expected output** (when the user types `7`):
# ```
# Odd number!
# ```
#
# The program should check if a number is even or odd using the modulus operator (`%`).

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0
    print("Even number!")
else:
    print("Odd number!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0
    print("Even number!")
else:
    print("Odd number!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 2 — Circle area
#
# **Expected output** (when the user types `6`):
# ```
# Area exceeds 100!
# ```
#
# The program calculates the area of a circle (`π × r²`) and checks if it exceeds 100.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

radius_input = input("Enter the radius: ")
radius = float(radius_input)
area = 3.14159 * radius ** 2
if area = 100:
    print("Area exceeds 100!")
else:
    print("Area is 100 or less")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
radius_input = input("Enter the radius: ")
radius = float(radius_input)
area = 3.14159 * radius ** 2
if area = 100:
    print("Area exceeds 100!")
else:
    print("Area is 100 or less")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 3 — Divisible by 3?
#
# **Expected output** (when the user types `9`):
# ```
# Divisible by 3!
# ```
#
# The program checks if a number is exactly divisible by 3 (remainder is 0).

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
remainder = number % 3
if remainder == 0:
print("Divisible by 3!")
else:
    print(f"Remainder is {remainder}")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
remainder = number % 3
if remainder == 0:
print("Divisible by 3!")
else:
    print(f"Remainder is {remainder}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 4 — Square check
#
# **Expected output** (when the user types `35`):
# ```
# Square is greater than 1000!
# ```
#
# The program squares a number and checks if the result is greater than 1000.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
squared = number ** 2
if squared < 1000:
    print("Square is greater than 1000!")
else:
    print("Square is 1000 or less")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
squared = number ** 2
if squared < 1000:
    print("Square is greater than 1000!")
else:
    print("Square is 1000 or less")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 5 — Favourite colour
#
# **Expected output** (when the user types `blue`):
# ```
# Nice choice!
# ```
#
# The program checks if the user's favourite colour is `"blue"`.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

colour = input("What is your favourite colour? ")
if colour == blue:
    print("Nice choice!")
else:
    print("That's a nice colour too!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
colour = input("What is your favourite colour? ")
if colour == blue:
    print("Nice choice!")
else:
    print("That's a nice colour too!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 6 — PIN check
#
# **Expected output** (when the user types `5678`):
# ```
# Wrong PIN!
# ```
#
# The program checks if the entered PIN is **not** `1234`.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

pin_input = input("Enter your PIN: ")
pin = int(pin_input)
if pin ! 1234:
    print("Wrong PIN!")
else:
    print("Access granted")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
pin_input = input("Enter your PIN: ")
pin = int(pin_input)
if pin ! 1234:
    print("Wrong PIN!")
else:
    print("Access granted")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 7 — Two errors
#
# **Expected output** (when the user types `8`):
# ```
# Correct answer!
# ```
#
# This program has **two** errors. Can you find and fix both?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

answer_input = input("What is 3 + 5? ")
if answer = 8
    print("Correct answer!")
else:
    print("Wrong answer!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
answer_input = input("What is 3 + 5? ")
if answer = 8
    print("Correct answer!")
else:
    print("Wrong answer!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 8 — Three errors
#
# **Expected output** (when the user types `140`):
# ```
# You can ride!
# ```
#
# This program has **three** errors. Can you find and fix all of them?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

height_input = input("Enter your height in cm: ")
height = int(height_input)
if height = 130
print("You can ride!")
else:
    print("Too short!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
height_input = input("Enter your height in cm: ")
height = int(height_input)
if height = 130
print("You can ride!")
else:
    print("Too short!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 9 — Four errors
#
# **Expected output** (when the user types `60`):
# ```
# You passed!
# ```
#
# This program has **four** errors. Take your time — read each line carefully!

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
if score = 50
print("You passed!")
else:
    print("You passed!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
if score = 50
print("You passed!")
else:
    print("You passed!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 10 — Five errors
#
# **Expected output** (when the user types `Bob`):
# ```
# Hello Bob!
# ```
#
# This is the hardest syntax exercise — it has **five** errors. You've got this!

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

name = input("Enter your name: ")
if name = Bob
print("Hello Bob!")
else:
    print("I don't know you")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
name = input("Enter your name: ")
if name = Bob
print("Hello Bob!")
else:
    print("I don't know you")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ---
#
# # Logic Errors
#
# The exercises above tested **syntax errors** — code that crashes immediately. The exercises below test **logic errors** — code that runs but produces the **wrong output**. These are harder to spot because Python doesn't give you an error message — you have to trace the logic yourself!
#
# ## Exercise 11 — Award certificate
#
# **Expected output** (when the user types `90`):
# ```
# Distinction
# ```
#
# The program checks if a score is 90 or above to award a Distinction. But it's not working correctly — can you spot why?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
if score > 90:
    print("Distinction")
else:
    print("Pass")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
if score > 90:
    print("Distinction")
else:
    print("Pass")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 12 — Age group
#
# **Expected output** (when the user types `12`):
# ```
# Child
# ```
#
# The program checks if someone is 12 or younger to label them as a Child. But it's not producing the correct output — can you spot why?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

age_input = input("Enter your age: ")
age = int(age_input)
if age < 12:
    print("Child")
else:
    print("Teenager")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
age_input = input("Enter your age: ")
age = int(age_input)
if age < 12:
    print("Child")
else:
    print("Teenager")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 13 — Positive or negative?
#
# **Expected output** (when the user types `5`):
# ```
# Positive
# ```
#
# The program should say Positive for numbers greater than 0 and Negative otherwise. But it's saying the wrong thing — trace through the logic carefully.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number < 0:
    print("Positive")
else:
    print("Negative")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number < 0:
    print("Positive")
else:
    print("Negative")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 14 — Password check
#
# **Expected output** (when the user types `python`):
# ```
# Correct password!
# ```
#
# The program should accept the password `"python"` and reject everything else. But it's doing the opposite — can you see why?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

password = input("Enter the password: ")
if password == "python":
    print("Wrong password!")
else:
    print("Correct password!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
password = input("Enter the password: ")
if password == "python":
    print("Wrong password!")
else:
    print("Correct password!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 15 — Temperature warning
#
# **Expected output** (when the user types `35`):
# ```
# It's hot!
# ```
#
# The program checks the temperature. Above 30 should be hot, 30 or below should be cold. But it's giving the wrong output — trace through the logic carefully to find the problem.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

temp_input = input("Enter the temperature: ")
temperature = int(temp_input)
if temperature > 30:
    print("It's cold!")
else:
    print("It's hot!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
temp_input = input("Enter the temperature: ")
temperature = int(temp_input)
if temperature > 30:
    print("It's cold!")
else:
    print("It's hot!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 16 — Even or odd?
#
# **Expected output** (when the user types `7`):
# ```
# Odd number
# ```
#
# The program should say Even or Odd for any number. But it's not producing output for all inputs — can you spot what's missing?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0:
    print("Even number")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0:
    print("Even number")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 17 — Valid age
#
# **Expected output** (when the user types `-5`):
# ```
# Invalid age
# ```
#
# The program should only accept ages between 0 and 150 as valid. But it's not working correctly for all inputs — can you spot the problem?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

age_input = input("Enter your age: ")
age = int(age_input)
if age <= 150:
    print("Valid age")
else:
    print("Invalid age")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
age_input = input("Enter your age: ")
age = int(age_input)
if age <= 150:
    print("Valid age")
else:
    print("Invalid age")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 18 — Grade calculator
#
# **Expected output** (when the user types `95`):
# ```
# Excellent score
# ```
#
# The program should check a score and say Excellent for 90 or above. But it's checking the wrong thing — read each variable name carefully!

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
age = 0
if age >= 90:
    print("Excellent score")
else:
    print("Good try")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
age = 0
if age >= 90:
    print("Excellent score")
else:
    print("Good try")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ---
#
# # Mixed Errors
#
# The final two exercises combine **syntax errors** AND **logic errors**. You'll need to find both kinds of bug to get the correct output. Take your time — read each line carefully!
#
# ## Exercise 19 — Number checker (2 errors)
#
# **Expected output** (when the user types `10`):
# ```
# Number is 10 or greater
# ```
#
# This program has **one syntax error** and **one logic error**. Can you find and fix both?

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number > 10
    print("Number is greater than 10")
else:
    print("Number is 10 or less")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number > 10
    print("Number is greater than 10")
else:
    print("Number is 10 or less")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 20 — Score checker (3 errors)
#
# **Expected output** (when the user types `75`):
# ```
# You passed!
# ```
#
# This is the final boss! It has **two syntax errors** and **one logic error**. You've got this!

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
if score >= 50
print("You failed!")
else:
    print("You passed!")

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
if score >= 50
print("You failed!")
else:
    print("You passed!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %% [markdown]
# ## Check your work
# Run the code below to find out if you have completed your tasks correctly

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

run_notebook_checks('ex002_selection_debug_if_then_else')
